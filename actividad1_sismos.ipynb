# %%
import numpy as np
import matplotlib.pyplot as plt
import obspy
from IPython.display import Image, display

# %% [markdown]
# <h1 style="text-align:center">Introducción a señales sísmicas con Obspy</h1>
# <h2 style="text-align:center"> ACUS125: Aislamiento y Análisis de Vibraciones </h2>
# <h3 style="text-align:center"> Primer semestre 2023 </h3>
#
# <p style="text-align:center"> <b>Profesor </b></p>
# <p style="text-align:center">Dr. Víctor Poblete R. <br>
# <a href="mailto:vpoblete@uach.cl">vpoblete@uach.cl</a><br>
#
# <p style="text-align:center"> <b>Ayudante </b></p>
#
# <p style="text-align:center">Rafael Peñailillo H.<br>
# <a href="mailto:vpoblete@uach.cl">rafael.penailillo@alumnos.uach.cl</a><br>

# %% [markdown]
# ## ¿Qué es un sismo? ¿Cómo se registra?
# ## ¿Cuáles son sus características?

# %%
display(Image(filename='M1U7-SF7.3-Seismogram.png'))

# %% [markdown]
# ### IRIS (Incorporated Research Institutions for Seismology) - Wilber: 3
# #### https://ds.iris.edu/wilber3/find_event

# %% [markdown]
# ## Librería Obspy
# ### Documentación 1.4.0: https://docs.obspy.org/

# %%
from obspy import read
st = read('http://examples.obspy.org/RJOB_061005_072159.ehz.new')
print(st)
# Out:
# 1 Trace(s) in Stream:
# .RJOB..Z | 2005-10-06T07:21:59.850000Z - 2005-10-06T07:24:59.845000Z | 200.0 Hz, 36000 samples

# %% [markdown]
# ### stream, trace objects

# %%
len(st)
# Out:
# 1

# %%
tr = st[0] #asignar la traza a una variable
print(tr)
# Out:
# .RJOB..Z | 2005-10-06T07:21:59.850000Z - 2005-10-06T07:24:59.845000Z | 200.0 Hz, 36000 samples

# %% [markdown]
# ### trace metadata

# %%
print(tr.stats)
# Out:
#          network:
#          station: RJOB
#         location:
#          channel: Z
#        starttime: 2005-10-06T07:21:59.850000Z
#          endtime: 2005-10-06T07:24:59.845000Z
#    sampling_rate: 200.0
#            delta: 0.005
#             npts: 36000
#            calib: 0.0949
#          _format: GSE2
#             gse2: AttribDict({'auxid': 'RJOB', 'datatype': 'CM6', 'calper': 1.0, 'instype': '', 'hang': -1.0, 'vang': -1.0, 'lat': -999.0, 'lon': -999.0, 'coordsys': '', 'elev': -0.999, 'edepth': -0.999})

# %%
tr.stats.station
# Out:
# 'RJOB'

# %%
tr.data
# Out:
# array([-38,  12,  -4, ..., -14,  -3,  -9])

# %% [markdown]
# ### data preview

# %%
st.plot(size=(800,400));

# %%
st.spectrogram(log=True, title='BW.RJOB')
# Out:
# [None]

# %% [markdown]
# ### Actividad: Importar y describir las señales de los eventos sísmicos dentro de la carpeta `data` utilizando la librería Obspy
